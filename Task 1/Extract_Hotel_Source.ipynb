# %%
import pandas as pd

rev1 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 1.csv', encoding='latin1')
rev2 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 2.csv', encoding='latin1')
rev3 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 3.csv', encoding='latin1')
rev4 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 4.csv', encoding='latin1')
rev5 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 5.csv', encoding='latin1')
rev6 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 6.csv', encoding='latin1')
rev7 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 7.csv', encoding='latin1')
rev8 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 8.csv', encoding='latin1')
rev9 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 9.csv', encoding='latin1')
rev10 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 10.csv', encoding='latin1')
rev11 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 11.csv', encoding='latin1')
rev12 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 12.csv', encoding='latin1')
rev13 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 13.csv', encoding='latin1')
rev14 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 14.csv', encoding='latin1')
rev15 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 15.csv', encoding='latin1')
rev16 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 16.csv', encoding='latin1')
rev17 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 17.csv', encoding='latin1')
rev18 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 18.csv', encoding='latin1')
rev19 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 19.csv', encoding='latin1')
rev20 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 20.csv', encoding='latin1')
rev21 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 21.csv', encoding='latin1')
rev22 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 22.csv', encoding='latin1')
rev23 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 23.csv', encoding='latin1')
rev24 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 24.csv', encoding='latin1')
rev25 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Review 25.csv', encoding='latin1')


concatenated_df = pd.concat([rev1, rev2, rev2, rev3, rev4, rev5, rev6, rev7, rev8, rev9, rev10, rev11, rev12, rev13, rev14, rev15, rev16, rev17, rev18, rev19, rev20, rev21, rev22, rev23, rev24, rev25])

concatenated_df.drop("Unnamed: 0", axis=1, inplace=True)

file_path = 'C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\concat_hotel_reviews.csv'

concatenated_df.to_csv(file_path, index=False)

print(f"Data saved to '{file_path}'")
# Out:
# Data saved to 'C:\Users\Arboy\Desktop\SP702\Capstone\Task 1\concat_hotel_reviews.csv'

# %%
concatenated_df = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\concat_hotel_reviews.csv')

print("DataFrame Information:")
print(concatenated_df.info())

print("\nMissing Values per Column:")
print(concatenated_df.isnull().sum())
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hotel Name  520 non-null    object
#  1   Author      514 non-null    object
#  2   Country     517 non-null    object
#  3   Review      517 non-null    object
# dtypes: object(4)
# memory usage: 16.7+ KB
# None
#
# Missing Values per Column:
# Hotel Name     9
# Author        15
# Country       12
# Review        12
# dtype: int64

# %%
concatenated_df.dropna(inplace=True)

concatenated_df.reset_index(drop=True, inplace=True)

file_path2 = 'C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\cleaned_hotel_reviews.csv'

concatenated_df.to_csv(file_path2, index=False)

print(f"Data saved to '{file_path2}'")
# Out:
# Data saved to 'C:\Users\Arboy\Desktop\SP702\Capstone\Task 1\cleaned_hotel_reviews.csv'

# %%
source = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel Source.csv', encoding='latin1')

print("DataFrame Information:")
print(source.info())

print("\nMissing Values per Column:")
print(source.isnull().sum())
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hotel Name       40 non-null     object
#  1   Address          40 non-null     object
#  2   Barangay         33 non-null     object
#  3   City Town        40 non-null     object
#  4   Province         40 non-null     object
#  5   Amenities        40 non-null     object
#  6    Price Range     36 non-null     object
#  7   Available Rooms  40 non-null     int64
#  8   Other Data       40 non-null     object
#  9   Reviews          40 non-null     int64
# dtypes: int64(2), object(8)
# memory usage: 3.3+ KB
# None
#
# Missing Values per Column:
# Hotel Name         0
# Address            0
# Barangay           7
# City Town          0
# Province           0
# Amenities          0
#  Price Range       4
# Available Rooms    0
# Other Data         0
# ...

# %%
source.dropna(inplace=True)

source.reset_index(drop=True, inplace=True)

filtered_df = source[source['Reviews'] > 30].head(25)

print("Filtered DataFrame Information:")
print(filtered_df.info())

print("\nFiltered DataFrame (First 25 hotels):")
print(filtered_df)
# Out:
# Filtered DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hotel Name       25 non-null     object
#  1   Address          25 non-null     object
#  2   Barangay         25 non-null     object
#  3   City Town        25 non-null     object
#  4   Province         25 non-null     object
#  5   Amenities        25 non-null     object
#  6    Price Range     25 non-null     object
#  7   Available Rooms  25 non-null     int64
#  8   Other Data       25 non-null     object
#  9   Reviews          25 non-null     int64
# dtypes: int64(2), object(8)
# memory usage: 2.1+ KB
# None
#
# Filtered DataFrame (First 25 hotels):
#                                            Hotel Name  \
# 0             Cauayan Island Resort and Spa (El Nido)
# 2                            Vellago Resort (El Nido)
# ...

# %%
import pandas as pd

df1 = filtered_df
df2 = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\cleaned_hotel_reviews.csv', encoding='latin1')

merged_df = pd.merge(df1, df2, on='Hotel Name', how='left')

file_path3 = 'C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel.csv'

merged_df.to_csv(file_path3, index=False)

print(f"Data saved to '{file_path3}'")
# Out:
# Data saved to 'C:\Users\Arboy\Desktop\SP702\Capstone\Task 1\Hotel.csv'

# %%
merged = pd.read_csv('C:\\Users\\Arboy\\Desktop\\SP702\\Capstone\\Task 1\\Hotel.csv', encoding='latin1')

print("DataFrame Information:")
print(merged.info())

print("\nMissing Values per Column:")
print(merged.isnull().sum())
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hotel Name       504 non-null    object
#  1   Address          504 non-null    object
#  2   Barangay         504 non-null    object
#  3   City Town        504 non-null    object
#  4   Province         504 non-null    object
#  5   Amenities        504 non-null    object
#  6    Price Range     504 non-null    object
#  7   Available Rooms  504 non-null    int64
#  8   Other Data       504 non-null    object
#  9   Reviews          504 non-null    int64
#  10  Author           504 non-null    object
#  11  Country          504 non-null    object
#  12  Review           504 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 51.3+ KB
# None
#
# Missing Values per Column:
# Hotel Name         0
# Address            0
# Barangay           0
# ...
